# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder

# =====================================================
# LOAD DATASET
# =====================================================

df = pd.read_csv('../datasets/Omnichannel Retail Data.csv')


print("\n========== DATASET LOADED ==========")
print(df.head())

# =====================================================
# DATASET INFO
# =====================================================

print("\n========== DATASET INFO ==========")
print(df.info())

print("\n========== DATASET SHAPE ==========")
print(df.shape)

# =====================================================
# CHECK MISSING VALUES
# =====================================================

print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())

# =====================================================
# REMOVE DUPLICATES
# =====================================================

print("\n========== DUPLICATES ==========")

duplicate_rows = df.duplicated().sum()

print("Duplicate Rows:", duplicate_rows)

df = df.drop_duplicates()

print("Duplicates Removed Successfully")

# =====================================================
# OUTLIER DETECTION
# =====================================================

print("\n========== OUTLIER DETECTION ==========")

numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - (1.5 * IQR)
    upper_bound = Q3 + (1.5 * IQR)

    outliers = df[
        (df[col] < lower_bound) |
        (df[col] > upper_bound)
    ]

    print(f"{col} --> {len(outliers)} outliers")

# =====================================================
# CHECK CATEGORICAL INCONSISTENCIES
# =====================================================

print("\n========== CATEGORICAL VALUES ==========")

categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:

    print(f"\nColumn: {col}")
    print(df[col].unique())

# =====================================================
# VALIDATE COLUMN RELATIONSHIPS
# =====================================================

print("\n========== VALIDATION CHECKS ==========")

# Selling Price > Market Price

invalid_price = df[
    df['Selling Price'] > df['Market Price']
]

print(
    "Selling Price > Market Price:",
    len(invalid_price)
)

# Discounts > Market Price

invalid_discount = df[
    df['Discounts'] > df['Market Price']
]

print(
    "Discounts > Market Price:",
    len(invalid_discount)
)

# Reorder Point > Stock Levels

invalid_reorder = df[
    df['Reorder Point'] > df['Stock Levels']
]

print(
    "Reorder Point > Stock Levels:",
    len(invalid_reorder)
)

# Return Rate > 100

invalid_return = df[
    df['Return Rate (%)'] > 100
]

print(
    "Return Rate > 100:",
    len(invalid_return)
)

# =====================================================
# CLEAN SALES / INVENTORY ANOMALIES
# =====================================================

print("\n========== CLEANING ANOMALIES ==========")

# Fix Selling Price

df['Selling Price'] = np.where(
    df['Selling Price'] > df['Market Price'],
    df['Market Price'],
    df['Selling Price']
)

# Fix Discounts

df['Discounts'] = np.where(
    df['Discounts'] > df['Market Price'],
    df['Market Price'],
    df['Discounts']
)

# Fix Reorder Point

df['Reorder Point'] = np.where(
    df['Reorder Point'] > df['Stock Levels'],
    df['Stock Levels'],
    df['Reorder Point']
)

print("Anomalies Cleaned Successfully")

# =====================================================
# ENCODE CATEGORICAL DATA
# =====================================================

print("\n========== ENCODING ==========")

label_cols = [
    'Promotions',
    'Demand Trend',
    'Customer Segments'
]

le = LabelEncoder()

for col in label_cols:

    df[col] = le.fit_transform(df[col])

# One Hot Encoding

df = pd.get_dummies(
    df,
    columns=['Category']
)

print("Encoding Completed")

# =====================================================
# SAVE CLEANED DATASET
# =====================================================

output_file = 'cleaned_omnichannel_retail_data.csv'

df.to_csv(
    output_file,
    index=False
)

# =====================================================
# FINAL OUTPUT
# =====================================================

print("\n========== FINAL OUTPUT ==========")

print(
    "Cleaned dataset saved as:",
    output_file
)

print(
    "Final Shape:",
    df.shape
)

print("\n========== TASK COMPLETED ==========")
# Out:
# ========== DATASET LOADED ==========
#    Product ID  Product Name         Category        Date  \
# 0        4277  Refrigerator  Home Appliances  2024-01-03
# 1        5406         Mixer  Home Appliances  2024-01-11
# 2        5617       T-Shirt          Fashion  2024-04-04
# 3        5617       T-Shirt          Fashion  2024-04-04
# 4        7315         Jeans          Fashion  2024-11-25
#
#   Online Store Location  Sales Quantity  Selling Price Promotions  \
# 0                Mumbai             330          24.38         No
# 1               Kolkata             429          24.83        Yes
# 2             Ahmedabad             298          13.41         No
# 3             Ahmedabad             298          13.41         No
# 4               Chennai             336          59.54        Yes
#
#   Demand Trend Customer Segments  ... Stockout Frequency  Reorder Point  \
# 0   Increasing           Regular  ...                 10             19
# 1   Decreasing           Premium  ...                 10            128
# 2       Stable           Regular  ...                 17            195
# 3       Stable           Regular  ...                 12             42
# 4       Stable           Premium  ...                 11             69
#
#    Order Fulfillment Time (days)  Retail Store Location  Market Price  \
# 0                              8              Bangalore         31.25
# 1                              6                 Mumbai         10.22
# 2                              9              Ahmedabad         87.52
# 3                              1              Ahmedabad         87.52
# 4                             11              Hyderabad         86.49
#
#   Competitor Prices  Discounts  Sales Volume  Return Rate (%)  \
# 0             54.64      22.15           207            18.61
# 1             14.24      40.19           268            17.19
# 2             54.64      49.52           328            15.77
# 3             54.64      49.52           328            15.77
# 4             16.88      11.80           428            14.80
#
#    Elasticity Index
# 0              1.28
# 1              2.23
# 2              1.79
# 3              1.79
# 4              0.51
#
# [5 rows x 22 columns]
#
# ========== DATASET INFO ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 12880 entries, 0 to 12879
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Product ID                     12880 non-null  int64
#  1   Product Name                   12880 non-null  str
#  2   Category                       12880 non-null  str
#  3   Date                           12880 non-null  str
#  4   Online Store Location          12880 non-null  str
#  5   Sales Quantity                 12880 non-null  int64
#  6   Selling Price                  12880 non-null  float64
#  7   Promotions                     12880 non-null  str
#  8   Demand Trend                   12880 non-null  str
#  9   Customer Segments              12880 non-null  str
#  10  Warehouse Location             12880 non-null  str
#  11  Stock Levels                   12880 non-null  int64
#  12  Stockout Frequency             12880 non-null  int64
#  13  Reorder Point                  12880 non-null  int64
#  14  Order Fulfillment Time (days)  12880 non-null  int64
#  15  Retail Store Location          12880 non-null  str
#  16  Market Price                   12880 non-null  float64
#  17  Competitor Prices              12880 non-null  float64
#  18  Discounts                      12880 non-null  float64
#  19  Sales Volume                   12880 non-null  int64
#  20  Return Rate (%)                12880 non-null  float64
#  21  Elasticity Index               12880 non-null  float64
# dtypes: float64(6), int64(7), str(9)
# memory usage: 3.0 MB
# None
#
# ========== DATASET SHAPE ==========
# (12880, 22)
#
# ========== MISSING VALUES ==========
# Product ID                       0
# Product Name                     0
# Category                         0
# Date                             0
# Online Store Location            0
# Sales Quantity                   0
# Selling Price                    0
# Promotions                       0
# Demand Trend                     0
# Customer Segments                0
# Warehouse Location               0
# Stock Levels                     0
# Stockout Frequency               0
# Reorder Point                    0
# Order Fulfillment Time (days)    0
# Retail Store Location            0
# Market Price                     0
# Competitor Prices                0
# Discounts                        0
# Sales Volume                     0
# Return Rate (%)                  0
# Elasticity Index                 0
# dtype: int64
#
# ========== DUPLICATES ==========
# Duplicate Rows: 0
# Duplicates Removed Successfully
#
# ========== OUTLIER DETECTION ==========
# Product ID --> 0 outliers
# Sales Quantity --> 0 outliers
# Selling Price --> 0 outliers
# Stock Levels --> 0 outliers
# Stockout Frequency --> 0 outliers
# Reorder Point --> 0 outliers
# Order Fulfillment Time (days) --> 0 outliers
# Market Price --> 0 outliers
# Competitor Prices --> 0 outliers
# Discounts --> 0 outliers
# Sales Volume --> 0 outliers
# Return Rate (%) --> 0 outliers
# Elasticity Index --> 0 outliers
#
# ========== CATEGORICAL VALUES ==========
#
# Column: Product Name
# <ArrowStringArray>
# [   'Refrigerator',           'Mixer',         'T-Shirt',           'Jeans',
#        'Bookshelf',          'Laptop',             'Fan',        'Keyboard',
#          'Monitor',            'Sofa',            'Desk',            'Rice',
#           'Snacks',        'Sneakers',            'Milk',          'Hoodie',
#            'Chair', 'Washing Machine',       'Microwave',           'Table',
#           'Coffee',           'Bread',      'Smartphone',          'Jacket',
#       'Headphones']
# Length: 25, dtype: str
#
# Column: Category
# <ArrowStringArray>
# ['Home Appliances', 'Fashion', 'Furniture', 'Electronics', 'Groceries']
# Length: 5, dtype: str
#
# Column: Date
# <ArrowStringArray>
# ['2024-01-03', '2024-01-11', '2024-04-04', '2024-11-25', '2024-11-13',
#  '2024-10-25', '2024-05-13', '2024-04-01', '2024-07-06', '2024-05-10',
#  ...
#  '2024-09-07', '2024-02-04', '2024-01-16', '2024-07-19', '2024-12-19',
#  '2024-10-14', '2024-03-04', '2024-12-13', '2024-09-21', '2024-05-24']
# Length: 365, dtype: str
#
# Column: Online Store Location
# <ArrowStringArray>
# [   'Mumbai',   'Kolkata', 'Ahmedabad',   'Chennai',     'Delhi', 'Bangalore',
#       'Pune', 'Hyderabad']
# Length: 8, dtype: str
#
# Column: Promotions
# <ArrowStringArray>
# ['No', 'Yes']
# Length: 2, dtype: str
#
# Column: Demand Trend
# <ArrowStringArray>
# ['Increasing', 'Decreasing', 'Stable']
# Length: 3, dtype: str
#
# Column: Customer Segments
# <ArrowStringArray>
# ['Regular', 'Premium', 'Budget']
# Length: 3, dtype: str
#
# Column: Warehouse Location
# <ArrowStringArray>
# [  'Chennai',   'Kolkata',      'Pune',     'Delhi', 'Bangalore', 'Hyderabad',
#  'Ahmedabad',    'Mumbai']
# Length: 8, dtype: str
#
# Column: Retail Store Location
# <ArrowStringArray>
# ['Bangalore',    'Mumbai', 'Ahmedabad', 'Hyderabad',     'Delhi',   'Chennai',
#    'Kolkata',      'Pune']
# Length: 8, dtype: str
#
# ========== VALIDATION CHECKS ==========
# Selling Price > Market Price: 6443
# Discounts > Market Price: 2693
# Reorder Point > Stock Levels: 1330
# Return Rate > 100: 0
#
# ========== CLEANING ANOMALIES ==========
# Anomalies Cleaned Successfully
#
# ========== ENCODING ==========
# Encoding Completed
#
# ========== FINAL OUTPUT ==========
# Cleaned dataset saved as: cleaned_omnichannel_retail_data.csv
# Final Shape: (12880, 26)
#
# ========== TASK COMPLETED ==========
# /var/folders/hf/578glp0j0wd97lq56xd2wv440000gn/T/ipykernel_27535/3020970150.py:77: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   categorical_cols = df.select_dtypes(include='object').columns
