# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Omnichannel Retail Data.csv")

# %%
df.head()
# Out:
#    Product ID  Product Name         Category        Date  \
# 0        4277  Refrigerator  Home Appliances  2024-01-03
# 1        5406         Mixer  Home Appliances  2024-01-11
# 2        5617       T-Shirt          Fashion  2024-04-04
# 3        5617       T-Shirt          Fashion  2024-04-04
# 4        7315         Jeans          Fashion  2024-11-25
#
#   Online Store Location  Sales Quantity  Selling Price Promotions  \
# 0                Mumbai             330          24.38         No
# 1               Kolkata             429          24.83        Yes
# 2             Ahmedabad             298          13.41         No
# 3             Ahmedabad             298          13.41         No
# 4               Chennai             336          59.54        Yes
#
#   Demand Trend Customer Segments  ... Stockout Frequency  Reorder Point  \
# 0   Increasing           Regular  ...                 10             19
# 1   Decreasing           Premium  ...                 10            128
# 2       Stable           Regular  ...                 17            195
# 3       Stable           Regular  ...                 12             42
# 4       Stable           Premium  ...                 11             69
#
#    Order Fulfillment Time (days)  Retail Store Location  Market Price  \
# 0                              8              Bangalore         31.25
# 1                              6                 Mumbai         10.22
# 2                              9              Ahmedabad         87.52
# 3                              1              Ahmedabad         87.52
# 4                             11              Hyderabad         86.49
#
#   Competitor Prices  Discounts  Sales Volume  Return Rate (%)  \
# 0             54.64      22.15           207            18.61
# 1             14.24      40.19           268            17.19
# 2             54.64      49.52           328            15.77
# 3             54.64      49.52           328            15.77
# 4             16.88      11.80           428            14.80
#
#    Elasticity Index
# 0              1.28
# 1              2.23
# 2              1.79
# 3              1.79
# 4              0.51
#
# [5 rows x 22 columns]

# %%
df.shape
# Out:
# (12880, 22)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12880 entries, 0 to 12879
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Product ID                     12880 non-null  int64
#  1   Product Name                   12880 non-null  object
#  2   Category                       12880 non-null  object
#  3   Date                           12880 non-null  object
#  4   Online Store Location          12880 non-null  object
#  5   Sales Quantity                 12880 non-null  int64
#  6   Selling Price                  12880 non-null  float64
#  7   Promotions                     12880 non-null  object
#  8   Demand Trend                   12880 non-null  object
#  9   Customer Segments              12880 non-null  object
#  10  Warehouse Location             12880 non-null  object
#  11  Stock Levels                   12880 non-null  int64
#  12  Stockout Frequency             12880 non-null  int64
#  13  Reorder Point                  12880 non-null  int64
#  14  Order Fulfillment Time (days)  12880 non-null  int64
#  15  Retail Store Location          12880 non-null  object
#  16  Market Price                   12880 non-null  float64
#  17  Competitor Prices              12880 non-null  float64
#  18  Discounts                      12880 non-null  float64
#  19  Sales Volume                   12880 non-null  int64
#  20  Return Rate (%)                12880 non-null  float64
#  21  Elasticity Index               12880 non-null  float64
# dtypes: float64(6), int64(7), object(9)
# memory usage: 2.2+ MB

# %%
df.describe()
# Out:
#          Product ID  Sales Quantity  Selling Price  Stock Levels  \
# count  12880.000000    12880.000000   12880.000000  12880.000000
# mean    5568.397438      250.862345      52.653249    504.406056
# std     2551.603244      144.492031      27.576372    290.195012
# min     1000.000000        1.000000       5.010000      0.000000
# 25%     3388.500000      126.000000      28.260000    255.000000
# 50%     5684.000000      250.000000      52.330000    497.000000
# 75%     7744.000000      376.000000      76.660000    757.000000
# max     9998.000000      499.000000      99.980000    999.000000
#
#        Stockout Frequency  Reorder Point  Order Fulfillment Time (days)  \
# count        12880.000000   12880.000000                   12880.000000
# mean             9.432609     104.993556                       7.462578
# std              5.828538      55.506320                       4.012133
# min              0.000000      10.000000                       1.000000
# 25%              4.000000      57.000000                       4.000000
# 50%              9.000000     106.000000                       7.000000
# 75%             14.000000     153.000000                      11.000000
# max             19.000000     199.000000                      14.000000
#
#        Market Price  Competitor Prices     Discounts  Sales Volume  \
# count  12880.000000       12880.000000  12880.000000  12880.000000
# mean      52.966769          52.486540     25.262783    245.208618
# std       27.221748          27.312972     14.515641    144.012953
# min        5.030000           5.020000      0.020000      1.000000
# 25%       30.102500          28.960000     12.700000    123.000000
# 50%       53.150000          52.270000     25.080000    240.000000
# 75%       76.900000          75.575000     37.920000    367.250000
# max       99.990000          99.990000     49.970000    499.000000
#
#        Return Rate (%)  Elasticity Index
# count     12880.000000      12880.000000
# mean          9.958283          1.502849
# std           5.797089          0.577084
# min           0.010000          0.500000
# 25%           4.850000          1.010000
# 50%          10.060000          1.500000
# 75%          14.930000          1.990000
# max          20.000000          2.500000

# %%
#Checking Missing Values

# %%
df.isnull().sum()
# Out:
# Product ID                       0
# Product Name                     0
# Category                         0
# Date                             0
# Online Store Location            0
# Sales Quantity                   0
# Selling Price                    0
# Promotions                       0
# Demand Trend                     0
# Customer Segments                0
# Warehouse Location               0
# Stock Levels                     0
# Stockout Frequency               0
# Reorder Point                    0
# Order Fulfillment Time (days)    0
# Retail Store Location            0
# Market Price                     0
# Competitor Prices                0
# Discounts                        0
# Sales Volume                     0
# Return Rate (%)                  0
# Elasticity Index                 0
# dtype: int64

# %%
#Removing Duplicate Values

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (12880, 22)

# %%
#Checking Inconsistent Values

# %%
df.nunique()
# Out:
# Product ID                       2780
# Product Name                       25
# Category                            5
# Date                              365
# Online Store Location               8
# Sales Quantity                    499
# Selling Price                    3641
# Promotions                          2
# Demand Trend                        3
# Customer Segments                   3
# Warehouse Location                  8
# Stock Levels                      986
# Stockout Frequency                 20
# Reorder Point                     190
# Order Fulfillment Time (days)      14
# Retail Store Location               8
# Market Price                     3636
# Competitor Prices                3634
# Discounts                        2986
# Sales Volume                      499
# Return Rate (%)                  1774
# Elasticity Index                  201
# dtype: int64

# %%
for col in df.select_dtypes(include='object').columns:
    print(col)
    print(df[col].unique())
# Out:
# Product Name
# ['Refrigerator' 'Mixer' 'T-Shirt' 'Jeans' 'Bookshelf' 'Laptop' 'Fan'
#  'Keyboard' 'Monitor' 'Sofa' 'Desk' 'Rice' 'Snacks' 'Sneakers' 'Milk'
#  '2024-05-17' '2024-03-19' '2024-01-10' '2024-02-03' '2024-11-10'
#  '2024-11-11' '2024-03-25' '2024-04-11' '2024-04-03' '2024-02-11'
#  '2024-01-04' '2024-06-07' '2024-08-06' '2024-12-08' '2024-09-22'
#  '2024-01-12' '2024-12-27' '2024-05-02' '2024-11-21' '2024-12-01'
#  '2024-11-27' '2024-12-02' '2024-06-06' '2024-09-17' '2024-08-31'
#  '2024-11-12' '2024-06-11' '2024-08-03' '2024-11-22' '2024-06-28'
#  '2024-10-16' '2024-10-05' '2024-11-23' '2024-09-23' '2024-05-26'
#  '2024-03-26' '2024-07-05' '2024-03-30' '2024-02-06' '2024-09-24'
#  '2024-09-07' '2024-02-04' '2024-01-16' '2024-07-19' '2024-12-19'
#  '2024-10-14' '2024-03-04' '2024-12-13' '2024-09-21' '2024-05-24']
# Online Store Location
# ['Mumbai' 'Kolkata' 'Ahmedabad' 'Chennai' 'Delhi' 'Bangalore' 'Pune'
#  'Hyderabad']
# Promotions
# ['No' 'Yes']
# Demand Trend
# ['Increasing' 'Decreasing' 'Stable']
# Customer Segments
# ['Regular' 'Premium' 'Budget']
# Warehouse Location
# ['Chennai' 'Kolkata' 'Pune' 'Delhi' 'Bangalore' 'Hyderabad' 'Ahmedabad'
#  'Mumbai']
# Retail Store Location
# ['Bangalore' 'Mumbai' 'Ahmedabad' 'Hyderabad' 'Delhi' 'Chennai' 'Kolkata'
#  'Pune']

# %%
#Handling Missing Values

# %%
df.fillna(0, inplace=True)

# %%
#Detecting Outliers

# %%
numeric_cols = df.select_dtypes(include=np.number).columns
numeric_cols
# Out:
# Index(['Product ID', 'Sales Quantity', 'Selling Price', 'Stock Levels',
#        'Stockout Frequency', 'Reorder Point', 'Order Fulfillment Time (days)',
#        'Market Price', 'Competitor Prices', 'Discounts', 'Sales Volume',
#        'Return Rate (%)', 'Elasticity Index'],
#       dtype='object')

# %%
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(col, len(outliers))
# Out:
# Product ID 0
# Sales Quantity 0
# Selling Price 0
# Stock Levels 0
# Stockout Frequency 0
# Reorder Point 0
# Order Fulfillment Time (days) 0
# Market Price 0
# Competitor Prices 0
# Discounts 0
# Sales Volume 0
# Return Rate (%) 0
# Elasticity Index 0

# %%
# Fixing incorrect data types
df['Date'] = pd.to_datetime(df['Date'])

# %%
# Converting numeric columns
df['Sales Volume'] = df['Sales Volume'].astype(float)

# %%
# Standardizing column names
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
# Formatting categorical values
df['category'] = df['category'].str.title()

# %%
# Formatting date column
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# %%
# Checking unique categorical values
df['category'].unique()
# Out:
# array(['Home Appliances', 'Fashion', 'Furniture', 'Electronics',
#        'Groceries'], dtype=object)

# %%
# Saving cleaned dataset
df.to_csv("Cleaned_Data.csv", index=False)
