# %% [markdown]
# # Importing The Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import random

# %% [markdown]
# # Loading All The Datasets

# %%
superStoreDf = pd.read_csv('/content/Superstore Dataset.csv', encoding = 'latin1')
demandDf = pd.read_csv('/content/demand_forecasting.csv')
inventoryDf = pd.read_csv('/content/inventory_monitoring.csv')
priceDf = pd.read_csv('/content/pricing_optimization.csv')

# %% [markdown]
# Getting The Size of The Dataset

# %%
print(superStoreDf.shape)
print(demandDf.shape)
print(inventoryDf.shape)
print(priceDf.shape)
# Out:
# (9994, 21)
# (10000, 10)
# (10000, 9)
# (10000, 10)

# %% [markdown]
# Getting All The Columns

# %%
print(superStoreDf.columns)
print(demandDf.columns)
print(inventoryDf.columns)
print(priceDf.columns)
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')
# Index(['Product ID', 'Date', 'Store ID', 'Sales Quantity', 'Price',
#        'Promotions', 'Seasonality Factors', 'External Factors', 'Demand Trend',
#        'Customer Segments'],
#       dtype='object')
# Index(['Product ID', 'Store ID', 'Stock Levels', 'Supplier Lead Time (days)',
#        'Stockout Frequency', 'Reorder Point', 'Expiry Date',
#        'Warehouse Capacity', 'Order Fulfillment Time (days)'],
#       dtype='object')
# Index(['Product ID', 'Store ID', 'Price', 'Competitor Prices', 'Discounts',
#        'Sales Volume', 'Customer Reviews', 'Return Rate (%)', 'Storage Cost',
#        'Elasticity Index'],
#       dtype='object')

# %% [markdown]
# **Observations**
# - We really don't need the Superstore Dataset because we can get the all the important attributes from the three datasets only.
# - So I will work on the three datasets only.

# %% [markdown]
# # Merging The Datasets
# 1. Checking The Datatypes of all the Three Dataset for merging

# %%
print(demandDf.dtypes)
print(inventoryDf.dtypes)
print(priceDf.dtypes)
# Out:
# Product ID               int64
# Date                    object
# Store ID                 int64
# Sales Quantity           int64
# Price                  float64
# Promotions              object
# Seasonality Factors     object
# External Factors        object
# Demand Trend            object
# Customer Segments       object
# dtype: object
# Product ID                        int64
# Store ID                          int64
# Stock Levels                      int64
# Supplier Lead Time (days)         int64
# Stockout Frequency                int64
# Reorder Point                     int64
# Expiry Date                      object
# Warehouse Capacity                int64
# Order Fulfillment Time (days)     int64
# dtype: object
# Product ID             int64
# Store ID               int64
# Price                float64
# Competitor Prices    float64
# Discounts            float64
# Sales Volume           int64
# Customer Reviews       int64
# Return Rate (%)      float64
# Storage Cost         float64
# Elasticity Index     float64
# dtype: object

# %% [markdown]
# **Observations**
# - As, two columns "StoreID" and "ProductID" is same in the three datasets and having the same datatype of integer we will use this to merge the datasets.

# %% [markdown]
# # Merging The Demand and Inventory Dataset

# %%
# mergedDf = pd.merge(
#     demandDf,
#     inventoryDf,
#     on = ['Product ID', 'Store ID'],
#     how = 'inner'
# )

# %% [markdown]
# **Observations**
# - When I use this and use the two columns i.e Product ID and Store ID the dataset size significantly reduce to the 122 records because sometimes it happens that Store ID not matched while Product ID matched so I have to try on the Product ID only

# %%
mergedDf = pd.merge(
    demandDf,
    inventoryDf,
    on = ['Product ID'],
    how = 'inner'
)

# %%
mergedDf.shape
# mergedDf.head().T
# Out:
# (11375, 18)

# %% [markdown]
# **Observations**
# - As we can see that the Store ID x and Store ID y have been created because it may possible that the product exists in multiple stores.
# - We need to get rid of it in our next section.
# - But first, merge the price dataset with it.

# %% [markdown]
# # Merging The Price Dataset with Merged Dataset.

# %%
mergedDf = pd.merge(
    mergedDf,
    priceDf,
    on = ['Product ID'],
    how = 'inner',
    suffixes = ('', '_pricing')
)

# %%
mergedDf.shape
# mergedDf.head(1).T
# Out:
# (12880, 27)

# %%
mergedDf.isnull().sum()
# Out:
# Product ID                          0
# Date                                0
# Store ID_x                          0
# Sales Quantity                      0
# Price                               0
# Promotions                          0
# Seasonality Factors              4170
# External Factors                 3244
# Demand Trend                        0
# Customer Segments                   0
# Store ID_y                          0
# Stock Levels                        0
# Supplier Lead Time (days)           0
# Stockout Frequency                  0
# Reorder Point                       0
# Expiry Date                         0
# Warehouse Capacity                  0
# Order Fulfillment Time (days)       0
# Store ID                            0
# Price_pricing                       0
# Competitor Prices                   0
# Discounts                           0
# Sales Volume                        0
# Customer Reviews                    0
# Return Rate (%)                     0
# Storage Cost                        0
# Elasticity Index                    0
# dtype: int64

# %% [markdown]
# # Finding The Unique Product IDs for imputing it with the Synthetic Data.

# %%
mergedDf['Product ID'].value_counts()
# Out:
# Product ID
# 7060    50
# 2557    48
# 3430    48
# 7940    40
# 1589    40
#         ..
# 9167     1
# 7372     1
# 2010     1
# 7388     1
# 8935     1
# Name: count, Length: 2780, dtype: int64

# %% [markdown]
# # Renaming The Columns For Store ID

# %%
mergedDf.rename(columns={

    'Store ID_x': 'Online Store ID',
    'Store ID_y': 'Warehouse ID',
    'Store ID': 'Retail Store ID',

    'Price': 'Selling Price',
    'Price_pricing': 'Market Price'

}, inplace=True)

mergedDf.head().T
# Out:
#                                                 0                   1  \
# Product ID                                   4277                5406
# Date                                   2024-01-03          2024-01-11
# Online Store ID                                48                  67
# Sales Quantity                                330                 429
# Selling Price                               24.38               24.83
# Promotions                                     No                 Yes
# Seasonality Factors                      Festival             Holiday
# External Factors               Competitor Pricing  Economic Indicator
# Demand Trend                           Increasing          Decreasing
# Customer Segments                         Regular             Premium
# Warehouse ID                                   44                  89
# Stock Levels                                   10                 296
# Supplier Lead Time (days)                       4                   2
# Stockout Frequency                             10                  10
# Reorder Point                                  19                 128
# Expiry Date                            2024-04-15          2024-11-28
# Warehouse Capacity                           1504                3169
# Order Fulfillment Time (days)                   8                   6
# Retail Store ID                                95                  90
# Market Price                                31.25               10.22
# Competitor Prices                           54.64               14.24
# Discounts                                   22.15               40.19
# Sales Volume                                  207                 268
# Customer Reviews                                1                   1
# Return Rate (%)                             18.61               17.19
# Storage Cost                                 1.38                9.11
# Elasticity Index                             1.28                2.23
#
#                                                 2                   3  \
# Product ID                                   5617                5617
# Date                                   2024-04-04          2024-04-04
# Online Store ID                                17                  17
# Sales Quantity                                298                 298
# Selling Price                               13.41               13.41
# Promotions                                     No                  No
# Seasonality Factors                           NaN                 NaN
# External Factors               Economic Indicator  Economic Indicator
# Demand Trend                               Stable              Stable
# Customer Segments                         Regular             Regular
# Warehouse ID                                   30                  86
# Stock Levels                                  807                 356
# Supplier Lead Time (days)                      26                  28
# Stockout Frequency                             17                  12
# Reorder Point                                 195                  42
# Expiry Date                            2024-11-20          2024-05-19
# Warehouse Capacity                           3533                1966
# Order Fulfillment Time (days)                   9                   1
# Retail Store ID                                20                  20
# Market Price                                87.52               87.52
# Competitor Prices                           54.64               54.64
# Discounts                                   49.52               49.52
# Sales Volume                                  328                 328
# Customer Reviews                                1                   1
# Return Rate (%)                             15.77               15.77
# Storage Cost                                  1.2                 1.2
# Elasticity Index                             1.79                1.79
#
#                                         4
# Product ID                           7315
# Date                           2024-11-25
# Online Store ID                         9
# Sales Quantity                        336
# Selling Price                       59.54
# Promotions                            Yes
# Seasonality Factors              Festival
# External Factors                      NaN
# Demand Trend                       Stable
# Customer Segments                 Premium
# Warehouse ID                           49
# Stock Levels                          493
# Supplier Lead Time (days)              14
# Stockout Frequency                     11
# Reorder Point                          69
# Expiry Date                    2024-03-18
# Warehouse Capacity                   4380
# Order Fulfillment Time (days)          11
# Retail Store ID                        96
# Market Price                        86.49
# Competitor Prices                   16.88
# Discounts                            11.8
# Sales Volume                          428
# Customer Reviews                        4
# Return Rate (%)                      14.8
# Storage Cost                         8.44
# Elasticity Index                     0.51

# %% [markdown]
# # Creating The Synthetic Data For Product ID and Store ID

# %%
product_categories = {

    "Electronics": [
        "Laptop",
        "Smartphone",
        "Keyboard",
        "Monitor",
        "Headphones"
    ],

    "Fashion": [
        "T-Shirt",
        "Jeans",
        "Sneakers",
        "Jacket",
        "Hoodie"
    ],

    "Furniture": [
        "Chair",
        "Desk",
        "Table",
        "Sofa",
        "Bookshelf"
    ],

    "Groceries": [
        "Rice",
        "Milk",
        "Coffee",
        "Snacks",
        "Bread"
    ],

    "Home Appliances": [
        "Microwave",
        "Fan",
        "Mixer",
        "Refrigerator",
        "Washing Machine"
    ]
}

# %% [markdown]
# # Imputing It With The Product ID
# - For this, I will create the product mapping which will helps us to impute the product name with product IDs

# %%
product_mapping = {}

unique_products = mergedDf[
    'Product ID'
].unique()

for product_id in unique_products:

    category = random.choice(
        list(product_categories.keys())
    )

    product_name = random.choice(
        product_categories[category]
    )

    product_mapping[product_id] = {

        'Product Name': product_name,
        'Category': category

    }

# %% [markdown]
# # Mapping The Product Name and Category with appropriate Product ID

# %%
mergedDf['Product Name'] = mergedDf[
    'Product ID'
].map(

    lambda x:
    product_mapping[x]['Product Name']

)

mergedDf['Category'] = mergedDf[
    'Product ID'
].map(

    lambda x:
    product_mapping[x]['Category']

)

# %%
mergedDf.head(1).T
# Out:
#                                                 0
# Product ID                                   4277
# Date                                   2024-01-03
# Online Store ID                                48
# Sales Quantity                                330
# Selling Price                               24.38
# Promotions                                     No
# Seasonality Factors                      Festival
# External Factors               Competitor Pricing
# Demand Trend                           Increasing
# Customer Segments                         Regular
# Warehouse ID                                   44
# Stock Levels                                   10
# Supplier Lead Time (days)                       4
# Stockout Frequency                             10
# Reorder Point                                  19
# Expiry Date                            2024-04-15
# Warehouse Capacity                           1504
# Order Fulfillment Time (days)                   8
# Retail Store ID                                95
# Market Price                                31.25
# Competitor Prices                           54.64
# Discounts                                   22.15
# Sales Volume                                  207
# Customer Reviews                                1
# Return Rate (%)                             18.61
# Storage Cost                                 1.38
# Elasticity Index                             1.28
# Product Name                         Refrigerator
# Category                          Home Appliances

# %% [markdown]
# # Imputing The Store IDs with proper Synthetic Store Name

# %%
online_store_names = [

    "QuickCart Online",
    "ShopEase Online",
    "MegaBuy Online",
    "UrbanCart",
    "SmartBasket"

]

warehouse_names = [

    "Central Warehouse",
    "North Distribution Hub",
    "Prime Storage",
    "Logistics Hub",
    "Supply Chain Center"

]

retail_store_names = [

    "City Retail Mart",
    "Retail Express",
    "Downtown Store",
    "Value Retail Store",
    "SuperMart Outlet"

]

# Creating The Locations Also To Track Which city have the most revenue
locations = [

    "Ahmedabad",
    "Mumbai",
    "Delhi",
    "Pune",
    "Bangalore",
    "Hyderabad",
    "Chennai",
    "Kolkata"

]

# %%
print(
    mergedDf['Online Store ID'].value_counts()
)
print(
    mergedDf['Online Store ID'].value_counts()
)
print(
    mergedDf['Warehouse ID'].value_counts()
)
# Out:
# Online Store ID
# 29    194
# 72    186
# 94    182
# 40    181
# 78    175
#      ...
# 52     92
# 69     91
# 30     87
# 79     87
# 63     84
# Name: count, Length: 99, dtype: int64
# Online Store ID
# 29    194
# 72    186
# 94    182
# 40    181
# 78    175
#      ...
# 52     92
# 69     91
# 30     87
# 79     87
# 63     84
# Name: count, Length: 99, dtype: int64
# Warehouse ID
# 53    193
# 34    176
# 70    175
# 51    173
# 38    172
#      ...
# 46     98
# 99     97
# 77     95
# 64     90
# 73     87
# Name: count, Length: 99, dtype: int64

# %% [markdown]
# # Creating The Same Mapping for it also

# %%
# For Online Store IDs
online_mapping = {}

for store_id in mergedDf[
    'Online Store ID'
].dropna().unique():

    online_mapping[store_id] = {

        'Store Name':
            random.choice(online_store_names),

        'Location':
            random.choice(locations)

    }

# For Warehouse Mapping

warehouseMapping = {}

for storeId in mergedDf[
    'Warehouse ID'
].dropna().unique():

    warehouseMapping[storeId] = {

        'Store Name':
            random.choice(warehouse_names),

        'Location':
            random.choice(locations)

    }

# For Retail Store Mapping
retailMapping = {}

for storeId in mergedDf[
    'Retail Store ID'
].dropna().unique():

    retailMapping[storeId] = {

        'Store Name':
            random.choice(retail_store_names),

        'Location':
            random.choice(locations)

    }

# %% [markdown]
# # Map The Store IDs

# %%
# Mapping Online Store ID
mergedDf['Online Store Name'] = mergedDf[
    'Online Store ID'
].map(

    lambda x:
    online_mapping[x]['Store Name']

)

mergedDf['Online Store Location'] = mergedDf[
    'Online Store ID'
].map(

    lambda x:
    online_mapping[x]['Location']

)

# Mapping Warehouse Store IDs
mergedDf['Warehouse Name'] = mergedDf[
    'Warehouse ID'
].map(

    lambda x:
    warehouseMapping[x]['Store Name']

)

mergedDf['Warehouse Location'] = mergedDf[
    'Warehouse ID'
].map(

    lambda x:
    warehouseMapping[x]['Location']

)

# Mapping Retail Store ID
mergedDf['Retail Store Name'] = mergedDf[
    'Retail Store ID'
].map(

    lambda x:
    retailMapping[x]['Store Name']

)

mergedDf['Retail Store Location'] = mergedDf[
    'Retail Store ID'
].map(

    lambda x:
    retailMapping[x]['Location']

)

# %% [markdown]
# # Checking The Final Dataset

# %%
mergedDf.head(1).T
# Out:
#                                                 0
# Product ID                                   4277
# Date                                   2024-01-03
# Online Store ID                                48
# Sales Quantity                                330
# Selling Price                               24.38
# Promotions                                     No
# Seasonality Factors                      Festival
# External Factors               Competitor Pricing
# Demand Trend                           Increasing
# Customer Segments                         Regular
# Warehouse ID                                   44
# Stock Levels                                   10
# Supplier Lead Time (days)                       4
# Stockout Frequency                             10
# Reorder Point                                  19
# Expiry Date                            2024-04-15
# Warehouse Capacity                           1504
# Order Fulfillment Time (days)                   8
# Retail Store ID                                95
# Market Price                                31.25
# Competitor Prices                           54.64
# Discounts                                   22.15
# Sales Volume                                  207
# Customer Reviews                                1
# Return Rate (%)                             18.61
# Storage Cost                                 1.38
# Elasticity Index                             1.28
# Product Name                         Refrigerator
# Category                          Home Appliances
# Online Store Name                QuickCart Online
# Online Store Location                      Mumbai
# Warehouse Name                  Central Warehouse
# Warehouse Location                        Chennai
# Retail Store Name                SuperMart Outlet
# Retail Store Location                   Bangalore

# %% [markdown]
# # Creating The Final Dataset With Appropriate Columns

# %%
final_columns = [
    'Product ID',
    'Product Name',
    'Category',
    'Date',
    'Online Store Location',
    'Sales Quantity',
    'Selling Price',
    'Promotions',
    'Demand Trend',
    'Customer Segments',
    'Warehouse Location',
    'Stock Levels',
    'Stockout Frequency',
    'Reorder Point',
    'Order Fulfillment Time (days)',
    'Retail Store Location',
    'Market Price',
    'Competitor Prices',
    'Discounts',
    'Sales Volume',
    'Return Rate (%)',
    'Elasticity Index'

]

# %%
final_columns = [
    col for col in final_columns
    if col in mergedDf.columns
]

# %%
finalDataset = mergedDf[
    final_columns
]

# %% [markdown]
# Checking The Shape, Columns and Preview

# %%
print("\nFinal Dataset Shape:")
print(finalDataset.shape)

print("\nFinal Columns:\n")
print(finalDataset.columns.tolist())
# Out:
# Final Dataset Shape:
# (12880, 22)
#
# Final Columns:
#
# ['Product ID', 'Product Name', 'Category', 'Date', 'Online Store Location', 'Sales Quantity', 'Selling Price', 'Promotions', 'Demand Trend', 'Customer Segments', 'Warehouse Location', 'Stock Levels', 'Stockout Frequency', 'Reorder Point', 'Order Fulfillment Time (days)', 'Retail Store Location', 'Market Price', 'Competitor Prices', 'Discounts', 'Sales Volume', 'Return Rate (%)', 'Elasticity Index']
#
# Preview:
#
#    Product ID  Product Name         Category        Date  \
# 0        4277  Refrigerator  Home Appliances  2024-01-03
# 1        5406         Mixer  Home Appliances  2024-01-11
# 2        5617       T-Shirt          Fashion  2024-04-04
# 3        5617       T-Shirt          Fashion  2024-04-04
# 4        7315         Jeans          Fashion  2024-11-25
#
#   Online Store Location  Sales Quantity  Selling Price Promotions  \
# 0                Mumbai             330          24.38         No
# 1               Kolkata             429          24.83        Yes
# 2             Ahmedabad             298          13.41         No
# 3             Ahmedabad             298          13.41         No
# 4               Chennai             336          59.54        Yes
#
#   Demand Trend Customer Segments  ... Stockout Frequency  Reorder Point  \
# 0   Increasing           Regular  ...                 10             19
# 1   Decreasing           Premium  ...                 10            128
# 2       Stable           Regular  ...                 17            195
# 3       Stable           Regular  ...                 12             42
# 4       Stable           Premium  ...                 11             69
#
#    Order Fulfillment Time (days)  Retail Store Location  Market Price  \
# 0                              8              Bangalore         31.25
# 1                              6                 Mumbai         10.22
# 2                              9              Ahmedabad         87.52
# 3                              1              Ahmedabad         87.52
# 4                             11              Hyderabad         86.49
#
#   Competitor Prices  Discounts  Sales Volume  Return Rate (%)  \
# 0             54.64      22.15           207            18.61
# 1             14.24      40.19           268            17.19
# 2             54.64      49.52           328            15.77
# 3             54.64      49.52           328            15.77
# 4             16.88      11.80           428            14.80
#
#    Elasticity Index
# 0              1.28
# 1              2.23
# 2              1.79
# 3              1.79
# 4              0.51
#
# [5 rows x 22 columns]

# %% [markdown]
# # Save The Final Dataset

# %%
finalDataset.to_csv('Omnichannel Retail Data.csv', index = False)
print("Dataset Saved Successfully")
# Out:
# Dataset Saved Successfully
